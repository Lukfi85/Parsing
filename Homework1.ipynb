# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.
#
# https://developer.github.com/v3/repos/#list-repositories-for-a-user

# %%
import requests as rq

# %%
user = "Lukfi85"
main_link = f'https://api.github.com/users/{user}/repos'
response = rq.get(main_link)
data = response.json()
with open('rep.json','wb') as f:
     f.write(response.content)

# %%
print(f'Список репозиториев пользователя {user}:')
for i in data:
    print(i['name'])
# Out:
# Список репозиториев пользователя Lukfi85:
# Data-Science
# database
# hello

# %%
data
# Out:
# [{'id': 262104737,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjIxMDQ3Mzc=',
#   'name': 'Data-Science',
#   'full_name': 'Lukfi85/Data-Science',
#   'private': False,
#   'owner': {'login': 'Lukfi85',
#    'id': 56842206,
#    'node_id': 'MDQ6VXNlcjU2ODQyMjA2',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/56842206?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lukfi85',
#    'html_url': 'https://github.com/Lukfi85',
#    'followers_url': 'https://api.github.com/users/Lukfi85/followers',
#    'following_url': 'https://api.github.com/users/Lukfi85/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Lukfi85/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Lukfi85/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Lukfi85/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Lukfi85/orgs',
#    'repos_url': 'https://api.github.com/users/Lukfi85/repos',
# ...

# %% [markdown]
# 2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
nt_link = "https://api.nytimes.com/svc/movies/v2/reviews/search.json"
review = "lebowski"
api_key = "tdWCKyabqT1U4YxB8bEaNQmpwcq6vLaB"
params = {'query':review,
         'api-key':api_key}
response_nt = requests.get(nt_link,params=params)
with open('review_nt.txt','wb') as f:
     f.write(response_nt.content)

# %%
response_nt.content
# Out:
# b'{"status":"OK","copyright":"Copyright (c) 2020 The New York Times Company. All Rights Reserved.","has_more":false,"num_results":1,"results":[{"display_title":"The Big Lebowski","mpaa_rating":"R","critics_pick":1,"byline":"Janet Maslin","headline":"Big Lebowski, the (Movie)","summary_short":"In a film both sweeter and loopier than &quot;Fargo,&quot; Joel and Ethan Coen and their rogues\' gallery of actors explore Southern California\'s post-hippie, surfer-dude bowling scene. The results are irresistible, at least for audiences on the film\'s laid-back wavelength and in tune with its deadpan humor. With shaggy, baggy looks that belie his performance\'s fine comic control, Jeff Bridges plays a guy who truly deserves to be called Dude, and is by turns oblivious and indignant once a ruined rug leads him into neo-noir escapades. In a film that certainly keeps its audience guessing what might happen next (Saddam Hussein renting bowling shoes?), John Turturro takes the cake as the most fie
# ...
